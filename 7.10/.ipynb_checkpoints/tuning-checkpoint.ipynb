# %%
import matplotlib.pyplot as plt
import numpy as np
from os import listdir
import seaborn as sns
from scipy.stats import gaussian_kde

# %%
def estimate_maxima(data):

    kde = gaussian_kde(data)

    samples = np.arange(min(data), max(data), 1e-9)

    probs = kde.evaluate(samples)
    maxima_index = probs.argmax()

    maxima = samples[maxima_index]

    return maxima

# %%
listdir()
# Out:
# ['++.csv',
#  '+-.csv',
#  '-+.csv',
#  '--.csv',
#  '-2Vred.csv',
#  '-3Vred.csv',
#  '-4Vred.csv',
#  '-5Vred.csv',
#  '.ipynb_checkpoints',
#  '0Vsmall.csv',
#  '20Vred-blue+.csv',
#  'a-1.csv',
#  'a-10.csv',
#  'a-11.csv',
#  'a-12.csv',
#  'a-13.csv',
#  'a-14.csv',
#  'a-15.csv',
#  'a-16.csv',
#  'a-17.csv',
#  'a-18.csv',
#  'a-19.csv',
#  'a-2.csv',
#  'a-20.csv',
#  'a-21.csv',
#  'a-22.csv',
#  'a-23.csv',
#  'a-24.csv',
#  'a-25.csv',
#  'a-26.csv',
#  'a-27.csv',
#  'a-28.csv',
#  'a-29.csv',
#  'a-3.csv',
#  'a-30.csv',
#  'a-31.csv',
#  'a-32.csv',
#  'a-33.csv',
#  'a-34.csv',
#  'a-35.csv',
#  'a-36.csv',
#  'a-37.csv',
#  'a-38.csv',
#  'a-39.csv',
#  'a-4.csv',
#  'a-40.csv',
#  'a-41.csv',
#  'a-42.csv',
#  'a-43.csv',
#  'a-44.csv',
#  'a-45.csv',
#  'a-5.csv',
#  'a-6.csv',
#  'a-7.csv',
#  'a-8.csv',
#  'a-9.csv',
#  'b-1.csv',
#  'b-10.csv',
#  'b-11.csv',
#  'b-12.csv',
#  'b-13.csv',
#  'b-14.csv',
#  'b-15.csv',
#  'b-16.csv',
#  'b-17.csv',
#  'b-18.csv',
#  'b-19.csv',
#  'b-2.csv',
#  'b-20.csv',
#  'b-21.csv',
#  'b-22.csv',
#  'b-23.csv',
#  'b-24.csv',
#  'b-25.csv',
#  'b-26.csv',
#  'b-27.csv',
#  'b-28.csv',
#  'b-29.csv',
#  'b-3.csv',
#  'b-30.csv',
#  'b-31.csv',
#  'b-32.csv',
#  'b-33.csv',
#  'b-34.csv',
#  'b-35.csv',
#  'b-36.csv',
#  'b-37.csv',
#  'b-38.csv',
#  'b-39.csv',
#  'b-4.csv',
#  'b-40.csv',
#  'b-41.csv',
#  'b-42.csv',
#  'b-43.csv',
#  'b-44.csv',
#  'b-45.csv',
#  'b-5.csv',
#  'b-6.csv',
#  'b-7.csv',
#  'b-8.csv',
#  'b-9.csv',
#  'b0.csv',
#  'b1.csv',
#  'b10.csv',
#  'b11.csv',
#  'b12.csv',
#  'b13.csv',
#  'b14.csv',
#  'b15.csv',
#  'b16.csv',
#  'b17.csv',
#  'b18.csv',
#  'b19.csv',
#  'b2.csv',
#  'b20.csv',
#  'b21.csv',
#  'b22.csv',
#  'b23.csv',
#  'b24.csv',
#  'b25.csv',
#  'b26.csv',
#  'b27.csv',
#  'b28.csv',
#  'b29.csv',
#  'b3.csv',
#  'b30.csv',
#  'b4.csv',
#  'b5.csv',
#  'b6.csv',
#  'b7.csv',
#  'b8.csv',
#  'b9.csv',
#  'nothing.csv',
#  'r-1.csv',
#  'r-10.csv',
#  'r-11.csv',
#  'r-12.csv',
#  'r-13.csv',
#  'r-14.csv',
#  'r-15.csv',
#  'r-16.csv',
#  'r-17.csv',
#  'r-18.csv',
#  'r-19.csv',
#  'r-2.csv',
#  'r-20.csv',
#  'r-21.csv',
#  'r-22.csv',
#  'r-23.csv',
#  'r-24.csv',
#  'r-25.csv',
#  'r-26.csv',
#  'r-27.csv',
#  'r-28.csv',
#  'r-29.csv',
#  'r-3.csv',
#  'r-30.csv',
#  'r-31.csv',
#  'r-32.csv',
#  'r-33.csv',
#  'r-34.csv',
#  'r-35.csv',
#  'r-36.csv',
#  'r-37.csv',
#  'r-38.csv',
#  'r-39.csv',
#  'r-4.csv',
#  'r-40.csv',
#  'r-41.csv',
#  'r-42.csv',
#  'r-43.csv',
#  'r-44.csv',
#  'r-45.csv',
#  'r-5.csv',
#  'r-6.csv',
#  'r-7.csv',
#  'r-8.csv',
#  'r-9.csv',
#  'r0.csv',
#  'r1.csv',
#  'r10.csv',
#  'r11.csv',
#  'r12.csv',
#  'r13.csv',
#  'r14.csv',
#  'r15.csv',
#  'r16.csv',
#  'r17.csv',
#  'r18.csv',
#  'r19.csv',
#  'r2.csv',
#  'r20.csv',
#  'r21.csv',
#  'r22.csv',
#  'r23.csv',
#  'r24.csv',
#  'r25.csv',
#  'r26.csv',
#  'r27.csv',
#  'r28.csv',
#  'r29.csv',
#  'r3.csv',
#  'r30.csv',
#  'r4.csv',
#  'r5.csv',
#  'r6.csv',
#  'r7.csv',
#  'r8.csv',
#  'r9.csv',
#  'tuning.ipynb']

# %%
# %matplotlib notebook
names = []

V = []
for name in listdir():
    
    if name[-3:]=='csv':
        #print(name)
        data = np.loadtxt(name, skiprows=15, delimiter=';',
                          usecols=(3), dtype='str')

        for i in range(len(data)):
            if data[i]==' No device found':
                data[i] = 0
            else:
                data[i] = data[i].replace(',', '.')
        #print(data)
        data = data.astype(np.float32)
        
        sns.displot(data, label=name, kde=True)
        
        V.append(estimate_maxima(data))
        
        names.append(int(name[:name.index('V')]))
        #fig = sns_plot.get_figure()
        #plt.plot(data, linewidth=1, label=name)
        plt.legend()
        plt.xlabel('V, Volt')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500.1333333333334">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-1ee24ff918f9> in <module>
#      22         V.append(estimate_maxima(data))
#      23
# ---> 24         names.append(int(name[:name.index('V')]))
#      25         #fig = sns_plot.get_figure()
#      26         #plt.plot(data, linewidth=1, label=name)
#
# ValueError: substring not found

# %%
plt.title('W(V) red')
plt.xlabel('V, Volt')
plt.ylabel('W, Watt')
plt.plot(names, V, '.')

# %%
b = np.arange(min(data), max(data), 1e-8)
#np.histogram(data, bins=b)

# %%
kde = sns.kdeplot(data)
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
data
# Out:
# array([9.17e-07, 9.12e-07, 9.07e-07, ..., 1.16e-06, 1.16e-06, 1.16e-06],
#       dtype=float32)

# %%
data = np.loadtxt('++.csv', skiprows=15, delimiter=';',
                          usecols=(3), dtype='str')

for i in range(len(data)):
    data[i] = data[i].replace(',', '.')
        
data = data.astype(np.float32)
#sns.displot(data, kde=True)
        
plt.plot(data, linewidth=1, label='++')


data = np.loadtxt('--.csv', skiprows=15, delimiter=';',
                          usecols=(3), dtype='str')

for i in range(len(data)):
    data[i] = data[i].replace(',', '.')
        
data = data.astype(np.float32)
#sns.displot(data, kde=True)
        
plt.plot(data, linewidth=1, label='--')

data = np.loadtxt('+-.csv', skiprows=15, delimiter=';',
                          usecols=(3), dtype='str')

for i in range(len(data)):
    data[i] = data[i].replace(',', '.')
        
data = data.astype(np.float32)
#sns.displot(data, kde=True)
        
plt.plot(data, linewidth=1, label='+-')

data = np.loadtxt('-+.csv', skiprows=15, delimiter=';',
                          usecols=(3), dtype='str')

for i in range(len(data)):
    data[i] = data[i].replace(',', '.')
        
data = data.astype(np.float32)
#sns.displot(data, kde=True)
        
plt.plot(data, linewidth=1, label='-+')


plt.xlabel('V, Volt')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
names = np.arange(-45, 31)
V_b = [0]*76
V_r = [0]*76

names_a = np.arange(-45, 0)*2
V_a = [0]*45

for name in listdir():
    if name[0]=='b' or name[0]=='r' or name[0]=='a':
        data = np.loadtxt(name, skiprows=15, delimiter=';',
                          usecols=(3), dtype='str')
        for i in range(len(data)):
            if data[i]==' No device found':
                data[i] = 0
            else:
                data[i] = data[i].replace(',', '.')
                
        data = data.astype(np.float32)
        
    if name[0]=='b':    
        V_b[45+int(name[1:name.index('.')])] = estimate_maxima(data)
    if name[0]=='r':    
        V_r[45+int(name[1:name.index('.')])] = estimate_maxima(data)
    if name[0]=='a':    
        V_a[45+int(name[1:name.index('.')])] = estimate_maxima(data)

        
V_b = np.array(V_b)        
V_r = np.array(V_r)
V_a = np.array(V_a)


plt.plot(names, V_b, '.-', color='steelblue', linewidth=0.5)
plt.plot(names, V_r, '.-', color='tomato', linewidth=0.5)
#plt.plot(names_a, V_a, '.-', color='plum', linewidth=0.5)

plt.plot(names_a, V_a, '--', color='plum')
plt.xlabel('V, Volt')
plt.ylabel('W, Watt')
plt.title('Сигнал на 2 выходе 3 мВт')
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">
# Text(0.5, 1.0, 'Сигнал на 2 выходе 3 мВт')

# %%
from scipy.optimize import curve_fit

def f(U, d_U, d_I):    
    alpha = 0.3e3 #
    x = (U-d_U)/(2*alpha)
    return np.cos(x)**2 + d_I

def g(U, d_U, alpha, d_I):
    return ((U-d_U)/(2*alpha))**2+d_I

I0 = 3e-3

plt.plot(names_a, f(names_a, 0,0))
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3,figsize=(9,4), sharey=True)

W = V_r/I0
U = names

ax1.plot(U, W, label='data_red', color='tomato')

popt, pcov = curve_fit(g, U, W)
ax1.plot(U, g(U, *popt), 'g--', label=r'$fit: \alpha=%5.1f $' % popt[1])
ax1.grid()
ax1.legend()
W = V_b/I0
U = names

ax2.plot(U, W, label='data_blue')

popt, pcov = curve_fit(g, U, W)
ax2.plot(U, g(U, *popt), 'g--', label=r'$fit: \alpha=%5.1f $' % popt[1])
ax2.legend()
ax2.grid()

W = V_a/I0
U = names_a

plt.plot(U, W, label='data_both')

popt, pcov = curve_fit(g, U, W)
ax3.plot(U, g(U, *popt), 'g--', label=r'$fit: \alpha=%5.1f $' % popt[1])
ax3.legend()
ax3.grid()
# Out:
# <img src="data:image/png;base64,..." width="899.8000000000001">

# %%
popt
# Out:
# array([-5.94852777e+01,  3.20926103e+02,  4.06909514e-03])

# %%
T =
